# %% [markdown]
# # MedCare-CLI - Demonstração Online
# Este notebook permite executar a aplicação MedCare-CLI diretamente no navegador.

# %%
# !git clone https://github.com/NelsonRibeiroFelix/medcare-cli.git
# %cd medcare-cli
# !pip install .
from src.main import main_menu
main_menu()
